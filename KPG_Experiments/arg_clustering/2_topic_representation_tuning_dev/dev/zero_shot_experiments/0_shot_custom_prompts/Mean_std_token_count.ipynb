# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
custom_1=pd.read_csv('/content/drive/MyDrive/Πτυχιακή/Code/Experiments_Meltemi/Track_2_KPG/arg_clustering/0_shot_custom_prompts/0_shot_custom_prompt_1/custom_1.csv')
custom_2=pd.read_csv('/content/drive/MyDrive/Πτυχιακή/Code/Experiments_Meltemi/Track_2_KPG/arg_clustering/0_shot_custom_prompts/0_shot_custom_prompt_2/custom_2.csv')
custom_3=pd.read_csv('/content/drive/MyDrive/Πτυχιακή/Code/Experiments_Meltemi/Track_2_KPG/arg_clustering/0_shot_custom_prompts/0_shot_custom_prompt_3/custom_3.csv')

# %%
custom_1 = custom_1[(custom_1['topic'] == 'Θα πρέπει να υιοθετήσουμε καθεστώς λιτότητας') & (custom_1['stance'] == -1)]
# Tokenize and calculate sentence lengths
custom_1['token_count'] = custom_1['Meltemi_Instruct'].apply(lambda x: len(word_tokenize(x)))

# Calculate the average sentence length
average_length = custom_1['token_count'].mean()
print(f"Average keypoint length in tokens: {average_length}")
# Calculate the variance in sentence length
std_length = custom_1['token_count'].std()
print(f"standard deviaation in sentence length: {std_length}")
# Out:
# Average keypoint length in tokens: 26.9
# standard deviaation in sentence length: 11.541711792932238

# %%
custom_1
# Out:
#     Topic  Count                                   Meltemi_Instruct  \
# 58     -1     22  Δεν θα πρέπει να υιοθετήσουμε ένα καθεστώς λιτ...
# 59      0     22  Τα καθεστώτα λιτότητας τείνουν να αυξάνουν τα ...
# 60      1     14  Ένα καθεστώς λιτότητας θα έβλαπτε τους ανθρώπο...
# 61      2     13  Ένα καθεστώς λιτότητας τιμωρεί άδικα τους φτωχ...
# 62      3     11  Δεν θα πρέπει να υιοθετήσουμε ένα καθεστώς λιτ...
# 63      4      7  Τα καθεστώτα λιτότητας μπορούν να έχουν αρνητι...
# 64      5      6  Ένα καθεστώς λιτότητας θα είχε καταστροφικές σ...
# 65      6      6  Δεν θα πρέπει να υιοθετήσουμε ένα καθεστώς λιτ...
# 66      7      4  Τα καθεστώτα λιτότητας μπορεί να εξοικονομούν ...
# 67      8      3  Η κυβέρνση είναι ήδη πολύ ελεγκτική και οι άνθ...
#
#                                   Representative_Docs  \
# 58  ['η λιτότητα συνήθως αφαιρεί από τους φτωχούς ...
# 59  ['το κόστος ενός καθεστώτος λιτότητας είναι πο...
# ...

# %%
custom_2 = custom_2[(custom_2['topic'] == 'Θα πρέπει να υιοθετήσουμε καθεστώς λιτότητας') & (custom_2['stance'] == -1)]
# Tokenize and calculate sentence lengths
custom_2['token_count'] = custom_2['Meltemi_Instruct'].apply(lambda x: len(word_tokenize(x)))
# Calculate the average sentence length
average_length = custom_2['token_count'].mean()
print(f"Average keypoint length in tokens: {average_length}")

# Calculate the variance in sentence length
std_length = custom_2['token_count'].std()
print(f"standard deviaation in sentence length: {std_length}")
# Out:
# Average keypoint length in tokens: 25.3
# standard deviaation in sentence length: 16.865810254937518

# %%
custom_2
# Out:
#     Topic  Count                                   Meltemi_Instruct  \
# 57     -1     22  Η επένδυση στην εκπαίδευση των νέων είναι ο κα...
# 58      0     22  τα καθεστώτα λιτότητας τείνουν να αυξάνουν τα ...
# 59      1     14  Τα επιχειρήματα υποστηρίζουν ότι ένα καθεστώς ...
# 60      2     13  Τα επιχειρήματα υποστηρίζουν ότι ένα καθεστώς ...
# 61      3     11  Τα επιχειρήματα υποστηρίζουν ότι η υιοθέτηση ε...
# 62      4      7  Τα καθεστώτα λιτότητας μπορούν να οδηγήσουν σε...
# 63      5      6      ένα καθεστώς λιτότητας θα είναι καταστροφικό.
# 64      6      6  Οι άνθρωποι θα πρέπει να είναι ελεύθεροι να κα...
# 65      7      4  Τα καθεστώτα λιτότητας μπορεί να εξοικονομούν ...
# 66      8      3               η κυβέρνση είναι εντάξει όπως είναι.
#
#                                   Representative_Docs  \
# 57  ['η λιτότητα συνήθως αφαιρεί από τους φτωχούς ...
# 58  ['το κόστος ενός καθεστώτος λιτότητας είναι πο...
# ...

# %%
custom_3 = custom_3[(custom_3['topic'] == 'Θα πρέπει να υιοθετήσουμε καθεστώς λιτότητας') & (custom_3['stance'] == -1)]
# Tokenize and calculate sentence lengths
custom_3['token_count'] = custom_3['Meltemi_Instruct'].apply(lambda x: len(word_tokenize(x)))
# Calculate the average sentence length
average_length = custom_3['token_count'].mean()
print(f"Average keypoint length in tokens: {average_length}")

# Calculate the variance in sentence length
std_length = custom_3['token_count'].std()
print(f"standard deviaation in sentence length: {std_length}")
# Out:
# Average keypoint length in tokens: 18.4
# standard deviaation in sentence length: 12.877197762798481

# %%
custom_3
# Out:
#     Topic  Count                                   Meltemi_Instruct  \
# 70     -1     22  Επένδυση στην εκπαίδευση των νέων για την ανάπ...
# 71      0     22  τα καθεστώτα λιτότητας τείνουν να αυξάνουν τα ...
# 72      1     14  Η εφαρμογή μέτρων λιτότητας θα έβλαπτε τους αν...
# 73      2     13  Ένα καθεστώς λιτότητας τιμωρεί άδικα τους φτωχ...
# 74      3     11  Δεν θα πρέπει να υιοθετήσουμε ένα καθεστώς λιτ...
# 75      4      7  Οι πολιτικές λιτότητας μπορεί να οδηγήσουν σε ...
# 76      5      6      ένα καθεστώς λιτότητας θα είναι καταστροφικό.
# 77      6      6  Οι άνθρωποι έχουν το δικαίωμα να ξοδεύουν χρήμ...
# 78      7      4  Τα καθεστώτα λιτότητας μπορεί να εξοικονομούν ...
# 79      8      3               η κυβέρνση είναι εντάξει όπως είναι.
#
#                                   Representative_Docs  \
# 70  ['η λιτότητα συνήθως αφαιρεί από τους φτωχούς ...
# 71  ['το κόστος ενός καθεστώτος λιτότητας είναι πο...
# ...

# %% [markdown]
# #Reference keypoints

# %%
refs=pd.read_csv('/content/drive/MyDrive/Πτυχιακή/Code/Experiments_Meltemi/train_dev_test_dataset/key_points_human_translated_dev.csv')
refs

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

# Ensure you have the tokenizer data
nltk.download('punkt')

# Tokenize and calculate sentence lengths
refs['token_count'] = refs['key_point'].apply(lambda x: len(word_tokenize(x)))

# Calculate the average sentence length
average_length = refs['token_count'].mean()
# Calculate the variance in sentence length
std_length = refs['token_count'].std()

print(f"Average sentence length in tokens: {average_length}")
print(f"standard deviaation in sentence length: {std_length}")
# Out:
# Average sentence length in tokens: 7.805555555555555
# standard deviaation in sentence length: 2.2144905179224077
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
